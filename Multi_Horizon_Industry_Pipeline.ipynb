# %% [markdown]
# # 멀티 호라이즌 섹터 예측 + 호라이즌별 인더스트리 클러스터링
#
# ## 워크플로우
# 1. 멀티 호라이즌 예측 (1d, 3d, 1w, 1m, 1q, 6m, 1y)
# 2. **각 호라이즌별로 독립적으로:**
#    - Top-3 섹터 선정
#    - 해당 섹터 내 인더스트리 클러스터링 (KMeans, 4개 클러스터)
#    - 결과를 `Data_set/Cluster_Results/`에 CSV로 저장
# 3. 전체 결과 JSON 저장

# %% [markdown]
# ## 1. 설정 및 데이터 로딩

# %%
import pandas as pd
import numpy as np
import json
import os
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

from src import MultiHorizonPredictor, IndustryClusterer

print("모듈 로딩 완료")
# Out:
# 모듈 로딩 완료

# %%
# 전체 데이터셋 로드 (Industry 컬럼이 포함된 주식 단위 데이터)
df_raw = pd.read_csv('Data_set/stock_features_clean.csv', parse_dates=['Date'])

print(f"데이터셋 로드: {len(df_raw):,} 행")
print(f"날짜 범위: {df_raw['Date'].min().date()} ~ {df_raw['Date'].max().date()}")
print(f"컬럼: {df_raw.columns.tolist()}")
print(f"\n섹터: {sorted(df_raw['Sector'].unique())}")
print(f"산업 수: {df_raw['Industry'].nunique()}")
print(f"기업 수: {df_raw['Company'].nunique()}")
# Out:
# 데이터셋 로드: 603,359 행
# 날짜 범위: 2020-11-27 ~ 2026-01-09
# 컬럼: ['Date', 'Company', 'Sector', 'Industry', 'Open', 'High', 'Low', 'Close', 'Volume', 'Daily_Return_raw', 'Daily_Return_calc', 'Cum_Return', 'Return_1M', 'Return_3M', 'Return_6M', 'MA_5', 'MA_20', 'MA_60', 'Volatility_20d', 'Drawdown', 'MDD', 'DD_Short', 'Vol_MA_20', 'Vol_Ratio', 'Vol_Std_20', 'Vol_Z_Score', 'Log_Volume', 'Log_Volume_W', 'RSI_14', 'BB_Upper', 'BB_Middle', 'BB_Lower', 'BB_Width', 'Dividends', 'Stock Splits', 'Daily_Return', 'Cum_Max', 'Prev_Close', 'Gap', 'Gap_Pct', 'Is_Extreme_Change']
#
# 섹터: ['Basic Materials', 'Communication Services', 'Consumer Cyclical', 'Consumer Defensive', 'Energy', 'Financial Services', 'Healthcare', 'Industrials', 'Real Estate', 'Technology', 'Utilities']
# 산업 수: 100
# 기업 수: 481

# %% [markdown]
# ## 2. 파라미터 설정

# %%
# 예측 파라미터
PREDICTION_DATE = pd.Timestamp('2026-01-16')  # 원하는 예측 기준일로 변경
TRAIN_YEARS = 4  # 학습 데이터 연도 수

# 모델 파라미터 (백테스트 최적화 결과)
ALPHA = 0.6  # 하이브리드 모델 가중치
GAMMA = 0.5  # 랭킹에서 신뢰도 가중치
TOP_K = 3    # 호라이즌별 상위 섹터 수

# 인더스트리 클러스터링 파라미터
N_CLUSTERS = 4  # 클러스터 개수
LOOKBACK_DAYS = 90  # 산업 특성 계산 기간 (일)

# 출력 디렉토리
OUTPUT_DIR = 'Data_set/Cluster_Results'
os.makedirs(OUTPUT_DIR, exist_ok=True)

print("파라미터:")
print(f"  예측 기준일: {PREDICTION_DATE.date()}")
print(f"  학습 연도: {TRAIN_YEARS}")
print(f"  Alpha: {ALPHA}")
print(f"  Gamma: {GAMMA}")
print(f"  Top-K: {TOP_K}")
print(f"  클러스터 수: {N_CLUSTERS}")
print(f"  특성 계산 기간: {LOOKBACK_DAYS}일")
print(f"  출력 디렉토리: {OUTPUT_DIR}")
# Out:
# 파라미터:
#   예측 기준일: 2026-01-16
#   학습 연도: 4
#   Alpha: 0.6
#   Gamma: 0.5
#   Top-K: 3
#   클러스터 수: 4
#   특성 계산 기간: 90일
#   출력 디렉토리: Data_set/Cluster_Results

# %% [markdown]
# ## 3. 멀티 호라이즌 예측을 위한 데이터 준비

# %%
# 섹터 단위로 집계 (일별 평균)
sector_df = df_raw.groupby(['Date', 'Sector'], as_index=False).agg({
    'Close': 'mean'
}).sort_values(['Sector', 'Date'])

print(f"섹터 집계: {len(sector_df):,} 행")

# 섹터 목록 추출
sectors = sorted(sector_df['Sector'].unique())
print(f"섹터: {sectors}")
# Out:
# 섹터 집계: 14,135 행
# 섹터: ['Basic Materials', 'Communication Services', 'Consumer Cyclical', 'Consumer Defensive', 'Energy', 'Financial Services', 'Healthcare', 'Industrials', 'Real Estate', 'Technology', 'Utilities']

# %% [markdown]
# ## 4. 멀티 호라이즌 예측

# %%
# 예측기 초기화
predictor = MultiHorizonPredictor(
    alpha=ALPHA,
    gamma=GAMMA,
    top_k=TOP_K
)

# 멀티 호라이즌 예측 실행
multi_horizon_results = predictor.predict_all_horizons(
    df=sector_df,
    prediction_date=PREDICTION_DATE,
    sectors=sectors,
    train_years=TRAIN_YEARS
)
# Out:
# 20:59:30 - cmdstanpy - INFO - Chain [1] start processing
# 2026-01-16 기준 멀티 호라이즌 예측
# 학습 데이터: 2022-01-18 ~ 2026-01-09
# 호라이즌: ['1d', '3d', '1w', '1m', '1q', '6m', '1y']
# ================================================================================
#
# [1d] 1일 호라이즌 예측 중...
# 20:59:30 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:30 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:30 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:31 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:31 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:31 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:31 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:32 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:32 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:32 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:32 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:33 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:33 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:33 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:33 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:33 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:34 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:34 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:34 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:34 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:35 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:35 - cmdstanpy - INFO - Chain [1] start processing
#   상위 3개 섹터: ['Healthcare', 'Real Estate', 'Basic Materials']
#
# [3d] 3일 호라이즌 예측 중...
# 20:59:35 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:35 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:36 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:36 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:36 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:36 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:37 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:37 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:37 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:37 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:37 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:38 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:38 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:38 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:38 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:39 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:39 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:39 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:39 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:40 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:40 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:40 - cmdstanpy - INFO - Chain [1] start processing
#   상위 3개 섹터: ['Financial Services', 'Basic Materials', 'Consumer Cyclical']
#
# [1w] 7일 호라이즌 예측 중...
# 20:59:40 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:41 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:41 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:41 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:41 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:41 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:42 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:42 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:42 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:42 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:43 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:43 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:43 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:43 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:44 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:44 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:44 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:44 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:45 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:45 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:45 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:45 - cmdstanpy - INFO - Chain [1] start processing
#   상위 3개 섹터: ['Financial Services', 'Basic Materials', 'Industrials']
#
# [1m] 30일 호라이즌 예측 중...
# 20:59:45 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:46 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:46 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:46 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:46 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:47 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:47 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:48 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:48 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:49 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:49 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:49 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:49 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:50 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:50 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:50 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:50 - cmdstanpy - INFO - Chain [1] start processing
#   상위 3개 섹터: ['Technology', 'Financial Services', 'Healthcare']
#
# [1q] 90일 호라이즌 예측 중...
# 20:59:51 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:51 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:51 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:51 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:52 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:52 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:52 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:52 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:52 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:53 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:53 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:53 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:53 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:54 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:54 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:54 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:54 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:55 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:55 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:55 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:55 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:56 - cmdstanpy - INFO - Chain [1] start processing
#   상위 3개 섹터: ['Financial Services', 'Basic Materials', 'Industrials']
#
# [6m] 180일 호라이즌 예측 중...
# 20:59:56 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:56 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:56 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:57 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:57 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:57 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:57 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:58 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:58 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:58 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:58 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:59 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:59 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:59 - cmdstanpy - INFO - Chain [1] start processing
# 20:59:59 - cmdstanpy - INFO - Chain [1] done processing
# 20:59:59 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:00 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:00 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:00 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:00 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:01 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:01 - cmdstanpy - INFO - Chain [1] start processing
#   상위 3개 섹터: ['Communication Services', 'Industrials', 'Financial Services']
#
# [1y] 365일 호라이즌 예측 중...
# 21:00:01 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:01 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:02 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:02 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:02 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:02 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:03 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:03 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:03 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:04 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:04 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:04 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:04 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:05 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:05 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:05 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:05 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:06 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:06 - cmdstanpy - INFO - Chain [1] done processing
# 21:00:06 - cmdstanpy - INFO - Chain [1] start processing
# 21:00:06 - cmdstanpy - INFO - Chain [1] done processing
#   상위 3개 섹터: ['Industrials', 'Financial Services', 'Technology']
#
# ================================================================================
# 멀티 호라이즌 예측 완료

# %%
# 호라이즌별 상위 섹터 출력
print("\n" + "="*80)
print("호라이즌별 상위 섹터")
print("="*80)
for horizon, result in multi_horizon_results.items():
    print(f"\n{horizon} ({result['horizon_days']}일):")
    for i, sector in enumerate(result['top_sectors'], 1):
        pred = result['predictions'][sector]
        conf = result['confidences'][sector]
        score = result['ranking_scores'][sector]
        print(f"  {i}. {sector:25s} | 예측: {pred:7.2%} | 신뢰도: {conf:.3f} | 점수: {score:6.2f}")
print("="*80)
# Out:
# ================================================================================
# 호라이즌별 상위 섹터
# ================================================================================
#
# 1d (1일):
#   1. Healthcare                | 예측:   4.08% | 신뢰도: 0.467 | 점수:   1.91
#   2. Real Estate               | 예측:   1.68% | 신뢰도: 0.510 | 점수:   0.92
#   3. Basic Materials           | 예측:   2.51% | 신뢰도: 0.449 | 점수:   0.90
#
# 3d (3일):
#   1. Financial Services        | 예측:   1.05% | 신뢰도: 0.476 | 점수:   1.69
#   2. Basic Materials           | 예측:   0.62% | 신뢰도: 0.507 | 점수:   1.11
#   3. Consumer Cyclical         | 예측:   0.68% | 신뢰도: 0.443 | 점수:   0.87
#
# 1w (7일):
#   1. Financial Services        | 예측:   1.60% | 신뢰도: 0.478 | 점수:   1.19
#   2. Basic Materials           | 예측:   1.26% | 신뢰도: 0.546 | 점수:   1.16
#   3. Industrials               | 예측:   1.50% | 신뢰도: 0.438 | 점수:   0.85
#
# 1m (30일):
#   1. Technology                | 예측:   5.83% | 신뢰도: 0.599 | 점수:   2.09
#   2. Financial Services        | 예측:   5.25% | 신뢰도: 0.445 | 점수:   0.91
#   3. Healthcare                | 예측:   5.37% | 신뢰도: 0.416 | 점수:   0.78
#
# 1q (90일):
#   1. Financial Services        | 예측:   1.34% | 신뢰도: 0.570 | 점수:   1.14
#   2. Basic Materials           | 예측:   4.18% | 신뢰도: 0.437 | 점수:   1.05
#   3. Industrials               | 예측:   5.40% | 신뢰도: 0.381 | 점수:   1.01
#
# 6m (180일):
#   1. Communication Services    | 예측:  21.32% | 신뢰도: 0.401 | 점수:   1.48
#   2. Industrials               | 예측:  19.69% | 신뢰도: 0.412 | 점수:   1.37
#   3. Financial Services        | 예측:  11.13% | 신뢰도: 0.529 | 점수:   1.28
#
# 1y (365일):
#   1. Industrials               | 예측:  28.21% | 신뢰도: 0.485 | 점수:   1.81
#   2. Financial Services        | 예측:  20.15% | 신뢰도: 0.521 | 점수:   1.44
#   3. Technology                | 예측:  21.08% | 신뢰도: 0.500 | 점수:   1.29
# ================================================================================

# %% [markdown]
# ## 5. 각 호라이즌별 인더스트리 클러스터링

# %%
# 클러스터러 초기화
clusterer = IndustryClusterer(
    n_clusters=N_CLUSTERS,
    random_state=42
)

# 각 호라이즌별로 클러스터링 수행
all_clustering_results = {}

date_str = PREDICTION_DATE.strftime('%Y%m%d')

for horizon_name, horizon_result in multi_horizon_results.items():
    print("\n" + "="*80)
    print(f"[{horizon_name}] 호라이즌 클러스터링 시작")
    print("="*80)
    
    # 해당 호라이즌의 Top-3 섹터
    top_sectors = horizon_result['top_sectors']
    print(f"선정된 섹터: {top_sectors}")
    
    # 클러스터링 수행
    clustering_result = clusterer.run_full_pipeline(
        df=df_raw,
        selected_sectors=top_sectors,
        lookback_days=LOOKBACK_DAYS,
        end_date=PREDICTION_DATE
    )
    
    # 결과 저장
    all_clustering_results[horizon_name] = clustering_result
    
    # CSV 파일로 저장
    # 1. 전체 산업 특성
    df_industry = clustering_result['industry_features']
    industry_filename = f"{OUTPUT_DIR}/{date_str}_{horizon_name}_industry_features.csv"
    df_industry.to_csv(industry_filename, index=False, encoding='utf-8-sig')
    print(f"\n저장: {industry_filename} ({len(df_industry)}개 산업)")
    
    # 2. 클러스터별 파일
    for cluster_name, df_cluster in clustering_result['by_cluster'].items():
        cluster_filename = f"{OUTPUT_DIR}/{date_str}_{horizon_name}_{cluster_name}.csv"
        df_cluster.to_csv(cluster_filename, index=False, encoding='utf-8-sig')
        print(f"저장: {cluster_filename} ({len(df_cluster)}개 산업)")
    
    print(f"\n[{horizon_name}] 완료")

print("\n" + "="*80)
print("모든 호라이즌 클러스터링 완료")
print("="*80)
# Out:
# ================================================================================
# [1d] 호라이즌 클러스터링 시작
# ================================================================================
# 선정된 섹터: ['Healthcare', 'Real Estate', 'Basic Materials']
#
# 산업 특성 추출 중...
# 기간: 2025-10-18 ~ 2026-01-16
# 섹터: ['Healthcare', 'Real Estate', 'Basic Materials']
# 산업 수: 25
# 25개 산업의 특성 추출 완료
#
# KMeans 클러스터링 완료
# 클러스터 수: 4
# 클러스터 분포: {0: 15, 1: 1, 2: 6, 3: 3}
#
# ================================================================================
# 클러스터 프로파일 (수익률 기준 정렬)
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 3           0.2173          0.3421 -0.1436        2.7154
# 0           0.0833          0.1789 -0.0688        1.9508
# 2          -0.0533          0.1915 -0.1156       -1.4084
# 1          -0.1602          0.3219 -0.2796       -2.3178
# ================================================================================
#
# 클러스터 재매핑 (수익률 기준):
#   Cluster 0: Return_3M = 21.73%
#   Cluster 1: Return_3M = 8.33%
#   Cluster 2: Return_3M = -5.33%
#   Cluster 3: Return_3M = -16.02%
#
# ================================================================================
# 클러스터 해석 (수익률 기준 정렬)
# ================================================================================
#
# CLUSTER_0: 공격형(고수익·고위험)
#   수익률: 21.73%, 변동성: 34.21%, MDD: -14.36%
#   샤프: 2.72
#   산업 (3개): Gold, Chemicals, Copper...
#   설명: 최고 수익률, 공격적 성장, 모멘텀 트레이딩에 적합
#
# CLUSTER_1: 최적형(최적 리스크-보상)
#   수익률: 8.33%, 변동성: 17.89%, MDD: -6.88%
#   샤프: 1.95
#   산업 (15개): Diagnostics & Research, Drug Manufacturers - General, Medical Devices, Medical Instruments & Supplies, Biotechnology...
#   설명: 우수한 위험 조정 수익률, 핵심 포트폴리오 보유 자산
#
# CLUSTER_2: 안정형(중립/저변동)
#   수익률: -5.33%, 변동성: 19.15%, MDD: -11.56%
#   샤프: -1.41
#   산업 (6개): REIT - Specialty, REIT - Residential, Real Estate Services, Healthcare Plans, REIT - Industrial...
#   설명: 안정적 성과, 포트폴리오 완충재, 리밸런싱 후보
#
# CLUSTER_3: 주의형(가치 함정)
#   수익률: -16.02%, 변동성: 32.19%, MDD: -27.96%
#   샤프: -2.32
#   산업 (1개): Health Information Services...
#   설명: 낮은 수익률과 높은 낙폭 위험, 회피 또는 언더웨이트
# ================================================================================
#
# 저장: Data_set/Cluster_Results/20260116_1d_industry_features.csv (25개 산업)
# 저장: Data_set/Cluster_Results/20260116_1d_cluster_0.csv (3개 산업)
# 저장: Data_set/Cluster_Results/20260116_1d_cluster_1.csv (15개 산업)
# 저장: Data_set/Cluster_Results/20260116_1d_cluster_2.csv (6개 산업)
# 저장: Data_set/Cluster_Results/20260116_1d_cluster_3.csv (1개 산업)
#
# [1d] 완료
#
# ================================================================================
# [3d] 호라이즌 클러스터링 시작
# ================================================================================
# 선정된 섹터: ['Financial Services', 'Basic Materials', 'Consumer Cyclical']
#
# 산업 특성 추출 중...
# 기간: 2025-10-18 ~ 2026-01-16
# 섹터: ['Financial Services', 'Basic Materials', 'Consumer Cyclical']
# 산업 수: 32
# 32개 산업의 특성 추출 완료
#
# KMeans 클러스터링 완료
# 클러스터 수: 4
# 클러스터 분포: {0: 4, 1: 16, 2: 3, 3: 9}
#
# ================================================================================
# 클러스터 프로파일 (수익률 기준 정렬)
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.2105          0.3189 -0.1456        2.8680
# 3           0.1871          0.1911 -0.0564        4.2661
# 1           0.0440          0.1835 -0.0743        1.1319
# 2          -0.0537          0.3463 -0.1796       -0.9847
# ================================================================================
#
# 클러스터 재매핑 (수익률 기준):
#   Cluster 0: Return_3M = 21.05%
#   Cluster 1: Return_3M = 18.71%
#   Cluster 2: Return_3M = 4.40%
#   Cluster 3: Return_3M = -5.37%
#
# ================================================================================
# 클러스터 해석 (수익률 기준 정렬)
# ================================================================================
#
# CLUSTER_0: 공격형(고수익·고위험)
#   수익률: 21.05%, 변동성: 31.89%, MDD: -14.56%
#   샤프: 2.87
#   산업 (4개): Gold, Chemicals, Copper, Resorts & Casinos...
#   설명: 최고 수익률, 공격적 성장, 모멘텀 트레이딩에 적합
#
# CLUSTER_1: 최적형(최적 리스크-보상)
#   수익률: 18.71%, 변동성: 19.11%, MDD: -5.64%
#   샤프: 4.27
#   산업 (9개): Banks - Diversified, Banks - Regional, Other Industrial Metals & Mining, Capital Markets, Lodging...
#   설명: 우수한 위험 조정 수익률, 핵심 포트폴리오 보유 자산
#
# CLUSTER_2: 안정형(중립/저변동)
#   수익률: 4.40%, 변동성: 18.35%, MDD: -7.43%
#   샤프: 1.13
#   산업 (16개): Travel Services, Insurance - Diversified, Insurance - Life, Insurance Brokers, Insurance - Property & Casualty...
#   설명: 안정적 성과, 포트폴리오 완충재, 리밸런싱 후보
#
# CLUSTER_3: 주의형(가치 함정)
#   수익률: -5.37%, 변동성: 34.63%, MDD: -17.96%
#   샤프: -0.98
#   산업 (3개): Internet Retail, Auto Parts, Footwear & Accessories...
#   설명: 낮은 수익률과 높은 낙폭 위험, 회피 또는 언더웨이트
# ================================================================================
#
# 저장: Data_set/Cluster_Results/20260116_3d_industry_features.csv (32개 산업)
# 저장: Data_set/Cluster_Results/20260116_3d_cluster_0.csv (4개 산업)
# 저장: Data_set/Cluster_Results/20260116_3d_cluster_1.csv (9개 산업)
# 저장: Data_set/Cluster_Results/20260116_3d_cluster_2.csv (16개 산업)
# 저장: Data_set/Cluster_Results/20260116_3d_cluster_3.csv (3개 산업)
#
# [3d] 완료
#
# ================================================================================
# [1w] 호라이즌 클러스터링 시작
# ================================================================================
# 선정된 섹터: ['Financial Services', 'Basic Materials', 'Industrials']
#
# 산업 특성 추출 중...
# 기간: 2025-10-18 ~ 2026-01-16
# 섹터: ['Financial Services', 'Basic Materials', 'Industrials']
# 산업 수: 34
# 34개 산업의 특성 추출 완료
#
# KMeans 클러스터링 완료
# 클러스터 수: 4
# 클러스터 분포: {0: 19, 1: 2, 2: 9, 3: 4}
#
# ================================================================================
# 클러스터 프로파일 (수익률 기준 정렬)
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 3           0.2212          0.3160 -0.1390        3.0699
# 0           0.1255          0.1897 -0.0519        2.9236
# 2          -0.0082          0.1767 -0.0939       -0.2138
# 1          -0.0502          0.3770 -0.1725       -0.5243
# ================================================================================
#
# 클러스터 재매핑 (수익률 기준):
#   Cluster 0: Return_3M = 22.12%
#   Cluster 1: Return_3M = 12.55%
#   Cluster 2: Return_3M = -0.82%
#   Cluster 3: Return_3M = -5.02%
#
# ================================================================================
# 클러스터 해석 (수익률 기준 정렬)
# ================================================================================
#
# CLUSTER_0: 공격형(고수익·고위험)
#   수익률: 22.12%, 변동성: 31.60%, MDD: -13.90%
#   샤프: 3.07
#   산업 (4개): Gold, Chemicals, Copper, Trucking...
#   설명: 최고 수익률, 공격적 성장, 모멘텀 트레이딩에 적합
#
# CLUSTER_1: 최적형(최적 리스크-보상)
#   수익률: 12.55%, 변동성: 18.97%, MDD: -5.19%
#   샤프: 2.92
#   산업 (19개): Insurance - Diversified, Insurance - Life, Insurance - Property & Casualty, Specialty Industrial Machinery, Aerospace & Defense...
#   설명: 우수한 위험 조정 수익률, 핵심 포트폴리오 보유 자산
#
# CLUSTER_2: 안정형(중립/저변동)
#   수익률: -0.82%, 변동성: 17.67%, MDD: -9.39%
#   샤프: -0.21
#   산업 (9개): Insurance Brokers, Asset Management, Specialty Chemicals, Credit Services, Building Products & Equipment...
#   설명: 안정적 성과, 포트폴리오 완충재, 리밸런싱 후보
#
# CLUSTER_3: 주의형(가치 함정)
#   수익률: -5.02%, 변동성: 37.70%, MDD: -17.25%
#   샤프: -0.52
#   산업 (2개): Engineering & Construction, Rental & Leasing Services...
#   설명: 낮은 수익률과 높은 낙폭 위험, 회피 또는 언더웨이트
# ================================================================================
#
# 저장: Data_set/Cluster_Results/20260116_1w_industry_features.csv (34개 산업)
# 저장: Data_set/Cluster_Results/20260116_1w_cluster_0.csv (4개 산업)
# 저장: Data_set/Cluster_Results/20260116_1w_cluster_1.csv (19개 산업)
# 저장: Data_set/Cluster_Results/20260116_1w_cluster_2.csv (9개 산업)
# 저장: Data_set/Cluster_Results/20260116_1w_cluster_3.csv (2개 산업)
#
# [1w] 완료
#
# ================================================================================
# [1m] 호라이즌 클러스터링 시작
# ================================================================================
# 선정된 섹터: ['Technology', 'Financial Services', 'Healthcare']
#
# 산업 특성 추출 중...
# 기간: 2025-10-18 ~ 2026-01-16
# 섹터: ['Technology', 'Financial Services', 'Healthcare']
# 산업 수: 31
# 31개 산업의 특성 추출 완료
#
# KMeans 클러스터링 완료
# 클러스터 수: 4
# 클러스터 분포: {0: 17, 1: 2, 2: 11, 3: 1}
#
# ================================================================================
# 클러스터 프로파일 (수익률 기준 정렬)
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 3           0.2461          0.4986 -0.0999        2.1043
# 0           0.1043          0.1697 -0.0599        2.6499
# 2          -0.0120          0.2049 -0.1179       -0.5041
# 1          -0.1675          0.3299 -0.2725       -2.3799
# ================================================================================
#
# 클러스터 재매핑 (수익률 기준):
#   Cluster 0: Return_3M = 24.61%
#   Cluster 1: Return_3M = 10.43%
#   Cluster 2: Return_3M = -1.20%
#   Cluster 3: Return_3M = -16.75%
#
# ================================================================================
# 클러스터 해석 (수익률 기준 정렬)
# ================================================================================
#
# CLUSTER_0: 공격형(고수익·고위험)
#   수익률: 24.61%, 변동성: 49.86%, MDD: -9.99%
#   샤프: 2.10
#   산업 (1개): Semiconductor Equipment & Materials...
#   설명: 최고 수익률, 공격적 성장, 모멘텀 트레이딩에 적합
#
# CLUSTER_1: 최적형(최적 리스크-보상)
#   수익률: 10.43%, 변동성: 16.97%, MDD: -5.99%
#   샤프: 2.65
#   산업 (17개): Diagnostics & Research, Drug Manufacturers - General, Medical Devices, Insurance - Diversified, Insurance - Life...
#   설명: 우수한 위험 조정 수익률, 핵심 포트폴리오 보유 자산
#
# CLUSTER_2: 안정형(중립/저변동)
#   수익률: -1.20%, 변동성: 20.49%, MDD: -11.79%
#   샤프: -0.50
#   산업 (11개): Consumer Electronics, Information Technology Services, Software - Application, Semiconductors, Insurance Brokers...
#   설명: 안정적 성과, 포트폴리오 완충재, 리밸런싱 후보
#
# CLUSTER_3: 주의형(가치 함정)
#   수익률: -16.75%, 변동성: 32.99%, MDD: -27.25%
#   샤프: -2.38
#   산업 (2개): Computer Hardware, Health Information Services...
#   설명: 낮은 수익률과 높은 낙폭 위험, 회피 또는 언더웨이트
# ================================================================================
#
# 저장: Data_set/Cluster_Results/20260116_1m_industry_features.csv (31개 산업)
# 저장: Data_set/Cluster_Results/20260116_1m_cluster_0.csv (1개 산업)
# 저장: Data_set/Cluster_Results/20260116_1m_cluster_1.csv (17개 산업)
# 저장: Data_set/Cluster_Results/20260116_1m_cluster_2.csv (11개 산업)
# 저장: Data_set/Cluster_Results/20260116_1m_cluster_3.csv (2개 산업)
#
# [1m] 완료
#
# ================================================================================
# [1q] 호라이즌 클러스터링 시작
# ================================================================================
# 선정된 섹터: ['Financial Services', 'Basic Materials', 'Industrials']
#
# 산업 특성 추출 중...
# 기간: 2025-10-18 ~ 2026-01-16
# 섹터: ['Financial Services', 'Basic Materials', 'Industrials']
# 산업 수: 34
# 34개 산업의 특성 추출 완료
#
# KMeans 클러스터링 완료
# 클러스터 수: 4
# 클러스터 분포: {0: 19, 1: 2, 2: 9, 3: 4}
#
# ================================================================================
# 클러스터 프로파일 (수익률 기준 정렬)
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 3           0.2212          0.3160 -0.1390        3.0699
# 0           0.1255          0.1897 -0.0519        2.9236
# 2          -0.0082          0.1767 -0.0939       -0.2138
# 1          -0.0502          0.3770 -0.1725       -0.5243
# ================================================================================
#
# 클러스터 재매핑 (수익률 기준):
#   Cluster 0: Return_3M = 22.12%
#   Cluster 1: Return_3M = 12.55%
#   Cluster 2: Return_3M = -0.82%
#   Cluster 3: Return_3M = -5.02%
#
# ================================================================================
# 클러스터 해석 (수익률 기준 정렬)
# ================================================================================
#
# CLUSTER_0: 공격형(고수익·고위험)
#   수익률: 22.12%, 변동성: 31.60%, MDD: -13.90%
#   샤프: 3.07
#   산업 (4개): Gold, Chemicals, Copper, Trucking...
#   설명: 최고 수익률, 공격적 성장, 모멘텀 트레이딩에 적합
#
# CLUSTER_1: 최적형(최적 리스크-보상)
#   수익률: 12.55%, 변동성: 18.97%, MDD: -5.19%
#   샤프: 2.92
#   산업 (19개): Insurance - Diversified, Insurance - Life, Insurance - Property & Casualty, Specialty Industrial Machinery, Aerospace & Defense...
#   설명: 우수한 위험 조정 수익률, 핵심 포트폴리오 보유 자산
#
# CLUSTER_2: 안정형(중립/저변동)
#   수익률: -0.82%, 변동성: 17.67%, MDD: -9.39%
#   샤프: -0.21
#   산업 (9개): Insurance Brokers, Asset Management, Specialty Chemicals, Credit Services, Building Products & Equipment...
#   설명: 안정적 성과, 포트폴리오 완충재, 리밸런싱 후보
#
# CLUSTER_3: 주의형(가치 함정)
#   수익률: -5.02%, 변동성: 37.70%, MDD: -17.25%
#   샤프: -0.52
#   산업 (2개): Engineering & Construction, Rental & Leasing Services...
#   설명: 낮은 수익률과 높은 낙폭 위험, 회피 또는 언더웨이트
# ================================================================================
#
# 저장: Data_set/Cluster_Results/20260116_1q_industry_features.csv (34개 산업)
# 저장: Data_set/Cluster_Results/20260116_1q_cluster_0.csv (4개 산업)
# 저장: Data_set/Cluster_Results/20260116_1q_cluster_1.csv (19개 산업)
# 저장: Data_set/Cluster_Results/20260116_1q_cluster_2.csv (9개 산업)
# 저장: Data_set/Cluster_Results/20260116_1q_cluster_3.csv (2개 산업)
#
# [1q] 완료
#
# ================================================================================
# [6m] 호라이즌 클러스터링 시작
# ================================================================================
# 선정된 섹터: ['Communication Services', 'Industrials', 'Financial Services']
#
# 산업 특성 추출 중...
# 기간: 2025-10-18 ~ 2026-01-16
# 섹터: ['Communication Services', 'Industrials', 'Financial Services']
# 산업 수: 31
# 31개 산업의 특성 추출 완료
#
# KMeans 클러스터링 완료
# 클러스터 수: 4
# 클러스터 분포: {0: 2, 1: 10, 2: 18, 3: 1}
#
# ================================================================================
# 클러스터 프로파일 (수익률 기준 정렬)
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 2           0.1250          0.1832 -0.0560        2.9397
# 0          -0.0502          0.3770 -0.1725       -0.5243
# 1          -0.0533          0.1575 -0.1134       -1.9550
# 3          -0.2896          0.3712 -0.3314       -3.9915
# ================================================================================
#
# 클러스터 재매핑 (수익률 기준):
#   Cluster 0: Return_3M = 12.50%
#   Cluster 1: Return_3M = -5.02%
#   Cluster 2: Return_3M = -5.33%
#   Cluster 3: Return_3M = -28.96%
#
# ================================================================================
# 클러스터 해석 (수익률 기준 정렬)
# ================================================================================
#
# CLUSTER_0: 공격형(고수익·고위험)
#   수익률: 12.50%, 변동성: 18.32%, MDD: -5.60%
#   샤프: 2.94
#   산업 (18개): Insurance - Diversified, Insurance - Life, Insurance - Property & Casualty, Specialty Industrial Machinery, Credit Services...
#   설명: 최고 수익률, 공격적 성장, 모멘텀 트레이딩에 적합
#
# CLUSTER_1: 최적형(최적 리스크-보상)
#   수익률: -5.02%, 변동성: 37.70%, MDD: -17.25%
#   샤프: -0.52
#   산업 (2개): Engineering & Construction, Rental & Leasing Services...
#   설명: 우수한 위험 조정 수익률, 핵심 포트폴리오 보유 자산
#
# CLUSTER_2: 안정형(중립/저변동)
#   수익률: -5.33%, 변동성: 15.75%, MDD: -11.34%
#   샤프: -1.96
#   산업 (10개): Insurance Brokers, Asset Management, Telecom Services, Internet Content & Information, Building Products & Equipment...
#   설명: 안정적 성과, 포트폴리오 완충재, 리밸런싱 후보
#
# CLUSTER_3: 주의형(가치 함정)
#   수익률: -28.96%, 변동성: 37.12%, MDD: -33.14%
#   샤프: -3.99
#   산업 (1개): Advertising Agencies...
#   설명: 낮은 수익률과 높은 낙폭 위험, 회피 또는 언더웨이트
# ================================================================================
#
# 저장: Data_set/Cluster_Results/20260116_6m_industry_features.csv (31개 산업)
# 저장: Data_set/Cluster_Results/20260116_6m_cluster_0.csv (18개 산업)
# 저장: Data_set/Cluster_Results/20260116_6m_cluster_1.csv (2개 산업)
# 저장: Data_set/Cluster_Results/20260116_6m_cluster_2.csv (10개 산업)
# 저장: Data_set/Cluster_Results/20260116_6m_cluster_3.csv (1개 산업)
#
# [6m] 완료
#
# ================================================================================
# [1y] 호라이즌 클러스터링 시작
# ================================================================================
# 선정된 섹터: ['Industrials', 'Financial Services', 'Technology']
#
# 산업 특성 추출 중...
# 기간: 2025-10-18 ~ 2026-01-16
# 섹터: ['Industrials', 'Financial Services', 'Technology']
# 산업 수: 36
# 36개 산업의 특성 추출 완료
#
# KMeans 클러스터링 완료
# 클러스터 수: 4
# 클러스터 분포: {0: 14, 1: 4, 2: 16, 3: 2}
#
# ================================================================================
# 클러스터 프로파일 (수익률 기준 정렬)
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 2           0.1357          0.1835 -0.0539        3.1897
# 1           0.0704          0.3891 -0.1207        0.7510
# 0          -0.0214          0.1749 -0.1047       -0.6713
# 3          -0.1172          0.3380 -0.2477       -1.5787
# ================================================================================
#
# 클러스터 재매핑 (수익률 기준):
#   Cluster 0: Return_3M = 13.57%
#   Cluster 1: Return_3M = 7.04%
#   Cluster 2: Return_3M = -2.14%
#   Cluster 3: Return_3M = -11.72%
#
# ================================================================================
# 클러스터 해석 (수익률 기준 정렬)
# ================================================================================
#
# CLUSTER_0: 공격형(고수익·고위험)
#   수익률: 13.57%, 변동성: 18.35%, MDD: -5.39%
#   샤프: 3.19
#   산업 (16개): Insurance - Diversified, Insurance - Life, Insurance - Property & Casualty, Specialty Industrial Machinery, Aerospace & Defense...
#   설명: 최고 수익률, 공격적 성장, 모멘텀 트레이딩에 적합
#
# CLUSTER_1: 최적형(최적 리스크-보상)
#   수익률: 7.04%, 변동성: 38.91%, MDD: -12.07%
#   샤프: 0.75
#   산업 (4개): Semiconductors, Semiconductor Equipment & Materials, Electronic Components, Engineering & Construction...
#   설명: 우수한 위험 조정 수익률, 핵심 포트폴리오 보유 자산
#
# CLUSTER_2: 안정형(중립/저변동)
#   수익률: -2.14%, 변동성: 17.49%, MDD: -10.47%
#   샤프: -0.67
#   산업 (14개): Consumer Electronics, Information Technology Services, Software - Application, Insurance Brokers, Asset Management...
#   설명: 안정적 성과, 포트폴리오 완충재, 리밸런싱 후보
#
# CLUSTER_3: 주의형(가치 함정)
#   수익률: -11.72%, 변동성: 33.80%, MDD: -24.77%
#   샤프: -1.58
#   산업 (2개): Computer Hardware, Rental & Leasing Services...
#   설명: 낮은 수익률과 높은 낙폭 위험, 회피 또는 언더웨이트
# ================================================================================
#
# 저장: Data_set/Cluster_Results/20260116_1y_industry_features.csv (36개 산업)
# 저장: Data_set/Cluster_Results/20260116_1y_cluster_0.csv (16개 산업)
# 저장: Data_set/Cluster_Results/20260116_1y_cluster_1.csv (4개 산업)
# 저장: Data_set/Cluster_Results/20260116_1y_cluster_2.csv (14개 산업)
# 저장: Data_set/Cluster_Results/20260116_1y_cluster_3.csv (2개 산업)
#
# [1y] 완료
#
# ================================================================================
# 모든 호라이즌 클러스터링 완료
# ================================================================================

# %% [markdown]
# ## 6. 호라이즌별 클러스터 프로파일 요약

# %%
# 각 호라이즌별 클러스터 프로파일 출력
print("\n" + "="*80)
print("호라이즌별 클러스터 프로파일 요약")
print("="*80)

for horizon_name in multi_horizon_results.keys():
    clustering_result = all_clustering_results[horizon_name]
    
    print(f"\n{'='*80}")
    print(f"[{horizon_name}] - Top 섹터: {', '.join(multi_horizon_results[horizon_name]['top_sectors'])}")
    print(f"{'='*80}")
    
    cluster_profile = clustering_result['cluster_profile']
    print(cluster_profile)
    
    print(f"\n클러스터별 산업 수:")
    for cluster_name, df_cluster in clustering_result['by_cluster'].items():
        interp = clustering_result['interpretations'][cluster_name]
        print(f"  {cluster_name}: {len(df_cluster):2d}개 산업 - {interp['label']}")

print("\n" + "="*80)
# Out:
# ================================================================================
# 호라이즌별 클러스터 프로파일 요약
# ================================================================================
#
# ================================================================================
# [1d] - Top 섹터: Healthcare, Real Estate, Basic Materials
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.2173          0.3421 -0.1436        2.7154
# 1           0.0833          0.1789 -0.0688        1.9508
# 2          -0.0533          0.1915 -0.1156       -1.4084
# 3          -0.1602          0.3219 -0.2796       -2.3178
#
# 클러스터별 산업 수:
#   cluster_0:  3개 산업 - 공격형(고수익·고위험)
#   cluster_1: 15개 산업 - 최적형(최적 리스크-보상)
#   cluster_2:  6개 산업 - 안정형(중립/저변동)
#   cluster_3:  1개 산업 - 주의형(가치 함정)
#
# ================================================================================
# [3d] - Top 섹터: Financial Services, Basic Materials, Consumer Cyclical
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.2105          0.3189 -0.1456        2.8680
# 1           0.1871          0.1911 -0.0564        4.2661
# 2           0.0440          0.1835 -0.0743        1.1319
# 3          -0.0537          0.3463 -0.1796       -0.9847
#
# 클러스터별 산업 수:
#   cluster_0:  4개 산업 - 공격형(고수익·고위험)
#   cluster_1:  9개 산업 - 최적형(최적 리스크-보상)
#   cluster_2: 16개 산업 - 안정형(중립/저변동)
#   cluster_3:  3개 산업 - 주의형(가치 함정)
#
# ================================================================================
# [1w] - Top 섹터: Financial Services, Basic Materials, Industrials
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.2212          0.3160 -0.1390        3.0699
# 1           0.1255          0.1897 -0.0519        2.9236
# 2          -0.0082          0.1767 -0.0939       -0.2138
# 3          -0.0502          0.3770 -0.1725       -0.5243
#
# 클러스터별 산업 수:
#   cluster_0:  4개 산업 - 공격형(고수익·고위험)
#   cluster_1: 19개 산업 - 최적형(최적 리스크-보상)
#   cluster_2:  9개 산업 - 안정형(중립/저변동)
#   cluster_3:  2개 산업 - 주의형(가치 함정)
#
# ================================================================================
# [1m] - Top 섹터: Technology, Financial Services, Healthcare
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.2461          0.4986 -0.0999        2.1043
# 1           0.1043          0.1697 -0.0599        2.6499
# 2          -0.0120          0.2049 -0.1179       -0.5041
# 3          -0.1675          0.3299 -0.2725       -2.3799
#
# 클러스터별 산업 수:
#   cluster_0:  1개 산업 - 공격형(고수익·고위험)
#   cluster_1: 17개 산업 - 최적형(최적 리스크-보상)
#   cluster_2: 11개 산업 - 안정형(중립/저변동)
#   cluster_3:  2개 산업 - 주의형(가치 함정)
#
# ================================================================================
# [1q] - Top 섹터: Financial Services, Basic Materials, Industrials
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.2212          0.3160 -0.1390        3.0699
# 1           0.1255          0.1897 -0.0519        2.9236
# 2          -0.0082          0.1767 -0.0939       -0.2138
# 3          -0.0502          0.3770 -0.1725       -0.5243
#
# 클러스터별 산업 수:
#   cluster_0:  4개 산업 - 공격형(고수익·고위험)
#   cluster_1: 19개 산업 - 최적형(최적 리스크-보상)
#   cluster_2:  9개 산업 - 안정형(중립/저변동)
#   cluster_3:  2개 산업 - 주의형(가치 함정)
#
# ================================================================================
# [6m] - Top 섹터: Communication Services, Industrials, Financial Services
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.1250          0.1832 -0.0560        2.9397
# 1          -0.0502          0.3770 -0.1725       -0.5243
# 2          -0.0533          0.1575 -0.1134       -1.9550
# 3          -0.2896          0.3712 -0.3314       -3.9915
#
# 클러스터별 산업 수:
#   cluster_0: 18개 산업 - 공격형(고수익·고위험)
#   cluster_1:  2개 산업 - 최적형(최적 리스크-보상)
#   cluster_2: 10개 산업 - 안정형(중립/저변동)
#   cluster_3:  1개 산업 - 주의형(가치 함정)
#
# ================================================================================
# [1y] - Top 섹터: Industrials, Financial Services, Technology
# ================================================================================
#          Return_3M  Volatility_20d     MDD  Sharpe_Ratio
# cluster
# 0           0.1357          0.1835 -0.0539        3.1897
# 1           0.0704          0.3891 -0.1207        0.7510
# 2          -0.0214          0.1749 -0.1047       -0.6713
# 3          -0.1172          0.3380 -0.2477       -1.5787
#
# 클러스터별 산업 수:
#   cluster_0: 16개 산업 - 공격형(고수익·고위험)
#   cluster_1:  4개 산업 - 최적형(최적 리스크-보상)
#   cluster_2: 14개 산업 - 안정형(중립/저변동)
#   cluster_3:  2개 산업 - 주의형(가치 함정)
#
# ================================================================================

# %% [markdown]
# ## 7. 호라이즌별 상위 산업 출력

# %%
# 각 호라이즌별로 Best Risk-Reward 클러스터의 상위 산업 출력
print("\n" + "="*80)
print("호라이즌별 추천 산업 (Best Risk-Reward 클러스터)")
print("="*80)

for horizon_name in multi_horizon_results.keys():
    clustering_result = all_clustering_results[horizon_name]
    
    print(f"\n[{horizon_name}]")
    print("-" * 80)
    
    # Best Risk-Reward 클러스터 찾기 (샤프 비율이 가장 높은 클러스터)
    best_cluster = None
    max_sharpe = -999
    
    for cluster_name, interp in clustering_result['interpretations'].items():
        if interp['sharpe_ratio'] > max_sharpe:
            max_sharpe = interp['sharpe_ratio']
            best_cluster = cluster_name
    
    if best_cluster:
        df_best = clustering_result['by_cluster'][best_cluster]
        interp = clustering_result['interpretations'][best_cluster]
        
        print(f"클러스터: {best_cluster} ({interp['label']})")
        print(f"샤프 비율: {interp['sharpe_ratio']:.2f}")
        print(f"\n상위 5개 산업:")
        
        for i, (idx, row) in enumerate(df_best.head(5).iterrows(), 1):
            print(f"  {i}. {row['Industry']:40s} | 섹터: {row['Sector']:20s} | 수익률: {row['Return_3M']:7.2%} | 샤프: {row['Sharpe_Ratio']:5.2f}")

print("\n" + "="*80)
# Out:
# ================================================================================
# 호라이즌별 추천 산업 (Best Risk-Reward 클러스터)
# ================================================================================
#
# [1d]
# --------------------------------------------------------------------------------
# 클러스터: cluster_0 (공격형(고수익·고위험))
# 샤프 비율: 2.72
#
# 상위 5개 산업:
#   1. Copper                                   | 섹터: Basic Materials      | 수익률:  29.60% | 샤프:  3.31
#   2. Chemicals                                | 섹터: Basic Materials      | 수익률:  23.54% | 샤프:  3.13
#   3. Gold                                     | 섹터: Basic Materials      | 수익률:  12.05% | 샤프:  1.71
#
# [3d]
# --------------------------------------------------------------------------------
# 클러스터: cluster_1 (최적형(최적 리스크-보상))
# 샤프 비율: 4.27
#
# 상위 5개 산업:
#   1. Specialty Retail                         | 섹터: Consumer Cyclical    | 수익률:  24.00% | 샤프:  5.05
#   2. Financial Conglomerates                  | 섹터: Financial Services   | 수익률:  22.44% | 샤프:  5.01
#   3. Banks - Regional                         | 섹터: Financial Services   | 수익률:  22.18% | 샤프:  7.19
#   4. Lodging                                  | 섹터: Consumer Cyclical    | 수익률:  20.81% | 샤프:  3.89
#   5. Capital Markets                          | 섹터: Financial Services   | 수익률:  18.01% | 샤프:  3.15
#
# [1w]
# --------------------------------------------------------------------------------
# 클러스터: cluster_0 (공격형(고수익·고위험))
# 샤프 비율: 3.07
#
# 상위 5개 산업:
#   1. Copper                                   | 섹터: Basic Materials      | 수익률:  29.60% | 샤프:  3.31
#   2. Chemicals                                | 섹터: Basic Materials      | 수익률:  23.54% | 샤프:  3.13
#   3. Trucking                                 | 섹터: Industrials          | 수익률:  23.28% | 샤프:  4.13
#   4. Gold                                     | 섹터: Basic Materials      | 수익률:  12.05% | 샤프:  1.71
#
# [1m]
# --------------------------------------------------------------------------------
# 클러스터: cluster_1 (최적형(최적 리스크-보상))
# 샤프 비율: 2.65
#
# 상위 5개 산업:
#   1. Financial Conglomerates                  | 섹터: Financial Services   | 수익률:  22.44% | 샤프:  5.01
#   2. Banks - Regional                         | 섹터: Financial Services   | 수익률:  22.18% | 샤프:  7.19
#   3. Capital Markets                          | 섹터: Financial Services   | 수익률:  18.01% | 샤프:  3.15
#   4. Drug Manufacturers - General             | 섹터: Healthcare           | 수익률:  16.76% | 샤프:  3.39
#   5. Banks - Diversified                      | 섹터: Financial Services   | 수익률:  13.62% | 샤프:  4.14
#
# [1q]
# --------------------------------------------------------------------------------
# 클러스터: cluster_0 (공격형(고수익·고위험))
# 샤프 비율: 3.07
#
# 상위 5개 산업:
#   1. Copper                                   | 섹터: Basic Materials      | 수익률:  29.60% | 샤프:  3.31
#   2. Chemicals                                | 섹터: Basic Materials      | 수익률:  23.54% | 샤프:  3.13
#   3. Trucking                                 | 섹터: Industrials          | 수익률:  23.28% | 샤프:  4.13
#   4. Gold                                     | 섹터: Basic Materials      | 수익률:  12.05% | 샤프:  1.71
#
# [6m]
# --------------------------------------------------------------------------------
# 클러스터: cluster_0 (공격형(고수익·고위험))
# 샤프 비율: 2.94
#
# 상위 5개 산업:
#   1. Integrated Freight & Logistics           | 섹터: Industrials          | 수익률:  29.75% | 샤프:  7.37
#   2. Trucking                                 | 섹터: Industrials          | 수익률:  23.28% | 샤프:  4.13
#   3. Financial Conglomerates                  | 섹터: Financial Services   | 수익률:  22.44% | 샤프:  5.01
#   4. Banks - Regional                         | 섹터: Financial Services   | 수익률:  22.18% | 샤프:  7.19
#   5. Capital Markets                          | 섹터: Financial Services   | 수익률:  18.01% | 샤프:  3.15
#
# [1y]
# --------------------------------------------------------------------------------
# 클러스터: cluster_0 (공격형(고수익·고위험))
# 샤프 비율: 3.19
#
# 상위 5개 산업:
#   1. Integrated Freight & Logistics           | 섹터: Industrials          | 수익률:  29.75% | 샤프:  7.37
#   2. Trucking                                 | 섹터: Industrials          | 수익률:  23.28% | 샤프:  4.13
#   3. Financial Conglomerates                  | 섹터: Financial Services   | 수익률:  22.44% | 샤프:  5.01
#   4. Banks - Regional                         | 섹터: Financial Services   | 수익률:  22.18% | 샤프:  7.19
#   5. Capital Markets                          | 섹터: Financial Services   | 수익률:  18.01% | 샤프:  3.15
#
# ================================================================================

# %% [markdown]
# ## 9. 최종 요약

# %%
print("\n" + "="*80)
print("파이프라인 최종 요약")
print("="*80)
print(f"예측 기준일: {PREDICTION_DATE.date()}")
print(f"\n멀티 호라이즌 예측:")
print(f"  분석된 호라이즌: {len(multi_horizon_results)}개")
print(f"  호라이즌별 Top 섹터 수: {TOP_K}개")

print(f"\n호라이즌별 클러스터링 결과:")
for horizon_name in multi_horizon_results.keys():
    clustering_result = all_clustering_results[horizon_name]
    top_sectors = multi_horizon_results[horizon_name]['top_sectors']
    n_industries = len(clustering_result['industry_features'])
    
    print(f"\n  [{horizon_name}]:")
    print(f"    선정 섹터: {', '.join(top_sectors)}")
    print(f"    분석된 산업: {n_industries}개")
    print(f"    클러스터: {N_CLUSTERS}개")
    
    # 클러스터별 산업 수
    cluster_dist = {}
    for cluster_name, df_cluster in clustering_result['by_cluster'].items():
        cluster_dist[cluster_name] = len(df_cluster)
    print(f"    클러스터 분포: {cluster_dist}")

print(f"\n저장된 파일:")
print(f"  출력 디렉토리: {OUTPUT_DIR}")
print(f"  CSV 파일: {len(multi_horizon_results) * (1 + N_CLUSTERS)}개")
print(f"    - 호라이즌별 industry_features.csv: {len(multi_horizon_results)}개")
print(f"    - 호라이즌별 클러스터 CSV: {len(multi_horizon_results) * N_CLUSTERS}개")

print("\n" + "="*80)
print("완료")
print("="*80)
# Out:
# ================================================================================
# 파이프라인 최종 요약
# ================================================================================
# 예측 기준일: 2026-01-16
#
# 멀티 호라이즌 예측:
#   분석된 호라이즌: 7개
#   호라이즌별 Top 섹터 수: 3개
#
# 호라이즌별 클러스터링 결과:
#
#   [1d]:
#     선정 섹터: Healthcare, Real Estate, Basic Materials
#     분석된 산업: 25개
#     클러스터: 4개
#     클러스터 분포: {'cluster_0': 3, 'cluster_1': 15, 'cluster_2': 6, 'cluster_3': 1}
#
#   [3d]:
#     선정 섹터: Financial Services, Basic Materials, Consumer Cyclical
#     분석된 산업: 32개
#     클러스터: 4개
#     클러스터 분포: {'cluster_0': 4, 'cluster_1': 9, 'cluster_2': 16, 'cluster_3': 3}
#
#   [1w]:
#     선정 섹터: Financial Services, Basic Materials, Industrials
#     분석된 산업: 34개
#     클러스터: 4개
#     클러스터 분포: {'cluster_0': 4, 'cluster_1': 19, 'cluster_2': 9, 'cluster_3': 2}
#
#   [1m]:
#     선정 섹터: Technology, Financial Services, Healthcare
#     분석된 산업: 31개
#     클러스터: 4개
#     클러스터 분포: {'cluster_0': 1, 'cluster_1': 17, 'cluster_2': 11, 'cluster_3': 2}
#
#   [1q]:
#     선정 섹터: Financial Services, Basic Materials, Industrials
#     분석된 산업: 34개
#     클러스터: 4개
#     클러스터 분포: {'cluster_0': 4, 'cluster_1': 19, 'cluster_2': 9, 'cluster_3': 2}
#
#   [6m]:
#     선정 섹터: Communication Services, Industrials, Financial Services
#     분석된 산업: 31개
#     클러스터: 4개
#     클러스터 분포: {'cluster_0': 18, 'cluster_1': 2, 'cluster_2': 10, 'cluster_3': 1}
#
#   [1y]:
#     선정 섹터: Industrials, Financial Services, Technology
#     분석된 산업: 36개
#     클러스터: 4개
#     클러스터 분포: {'cluster_0': 16, 'cluster_1': 4, 'cluster_2': 14, 'cluster_3': 2}
#
# 저장된 파일:
#   출력 디렉토리: Data_set/Cluster_Results
#   CSV 파일: 35개
#     - 호라이즌별 industry_features.csv: 7개
#     - 호라이즌별 클러스터 CSV: 28개
#
# ================================================================================
# 완료
# ================================================================================
